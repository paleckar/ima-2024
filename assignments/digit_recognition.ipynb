# %% [markdown]
# # Digit recognition

# %% [markdown]
# 1. Write at least 10 digits on a piece of paper using a marker, at least one example of each digit 0-9.
# 2. Detect and crop the digits out of the image.
# 3. Train a KNN or an SVM classifier using scikit-learn on the training set of MNIST digits dataset as demonstrated in the [classification lecutre](../lectures/classification.ipynb).
# 4. Recognize the 10+ digits from your image and calculate the accuracy. **It should be at least 60 %.**
#
# <figure class="image">
#   <img src="../figures/digit_recognition-example_outputs.png" alt="" style="width: 12.8in;"/>
#   <figcaption>Figure 1: Example outputs. The last row shows 28x28 preprocessed images that will be classified by the scikit-learn classifer.</figcaption>
# </figure>

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import skimage
from sklearn import datasets, linear_model, metrics, model_selection, neighbors, preprocessing, svm as sksvm

# %%
plt.rcParams['figure.constrained_layout.use'] = True
np.set_printoptions(threshold=20, edgeitems=10, linewidth=140, precision=3, suppress=True)

# %% [markdown]
# # Task 1: create an image of at least 10 hand-written digits

# %% [markdown]
# - Write down at least one example of each digit 0-9 on a paper and photograph it e.g. using your phone.
# - Load the image here.

# %%
########################################
# TODO: implement

digits_rgb = ...

# ENDTODO
########################################

# %%
plt.imshow(digits_rgb);

# %% [markdown]
# ## Task 2: detect and crop the digits out of the image

# %% [markdown]
# - Detect the digits e.g. using thresholding.
# - Find connected components.
# - Crop every component out of the image.
# - Normalize every cropped region to 28x28 pixels square window.
# - Make sure the 28x28 images
#   - are white digits on a black background,
#   - are padded with some border,
#   - display the digits roughly at their center,
#   - look as similar to MNIST data as possible.

# %%
########################################
# TODO: implement

# ...  find digits and preprocess
X_test = ... # should be a matrix of size (num_digits, 768)
y_test = ... # vector of size (num_digits,)

# ENDTODO
########################################

# %% [markdown]
# # Task 3: train a classifier

# %% [markdown]
# - Train either k-nearest neighbor or SVM classifier using scikit-learn library as demonstrated in the lecture.
# - Designate a subset of MNIST dataset for training your classifier. Again, see the lecture for how to do it using scikit-learn.

# %%
########################################
# TODO: implement

clf = ...
clf.fit(X_train, y_train)

# ENDTODO
########################################

# %% [markdown]
# # Task 4: recognize your digits using the trained classifier

# %% [markdown]
# - Create an `X_test` matrix from your cropped and normalized digits.
# - The matrix should be of shape  `(num_digits, 768)`.
# - Make sure `X_test` has the same data type (`dtype`) as numerical range as `X_train`.
# - Create a `y_test` vector of class labels (targets). For example, if `y_test[2] == 5`, it means that the window number 2 has shows the digit 5.
# - Use the trained classifier to predict what digits are in your image. This will give you `y_test_pred`.
# - Calculate the recognition accuracy by comparing the manually annotated (true) `y_test` labels with the predicted ones (`y_test_pred`).

# %%
########################################
# TODO: implement

# ...
clf.predict(X_test, y_test)

# ENDTODO
########################################
