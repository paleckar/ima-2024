# %% [markdown]
# # Object detection and registration

# %% [markdown]
# - In this assignment we're going to machine-read ID cards from arbitrary views.
# - We'll first develop the method step by step, then refactor it into single function and apply to other images.
# - You'll need the [easyocr](https://github.com/JaidedAI/EasyOCR) package for this assignment.
# - You can install it as
#   ```
#   pip install easyocr --ignore-installed
#   ```

# %%
import os

import cv2 as cv
import easyocr
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import skimage

# %% [markdown]
# # Load an image pair

# %%
plt.rcParams['figure.constrained_layout.use'] = True
np.set_printoptions(threshold=20, edgeitems=10, linewidth=140, precision=3, suppress=True)

# %%
obj_rgb = skimage.io.imread('../data/10_cze_id/10_cze_id_template.png')
obj_gray = skimage.color.rgb2gray(obj_rgb)

# %%
fig, axes = plt.subplots(1, 2)
axes[0].imshow(obj_rgb)
axes[1].imshow(obj_gray, cmap='gray', vmin=0, vmax=1);

# %%
scn_rgb = skimage.io.imread('../data/10_cze_id/TS10_01.jpg')
scn_gray = skimage.color.rgb2gray(scn_rgb)

# %%
fig, axes = plt.subplots(1, 2)
axes[0].imshow(scn_rgb)
axes[1].imshow(scn_gray, cmap='gray', vmin=0, vmax=1);

# %% [markdown]
# # Task 1: Locate the ID card (object in `obj_gray`) in the scene (`scn_gray`)

# %% [markdown]
# - Detect SIFT keypoints and compute their descriptors in both object and scene images.
# - For each *object* keypoint find the corresponding keypoint in the *scene* (matching). Apply the ratio test.
# - Find homography (perspective transformation) between the object and the scene.
# - Draw the results.
#
# <figure class="image">
#   <img src="../figures/object_detection-expected_detection_output.png" alt="" style="width: 6.4in;"/>
#   <figcaption>Figure 1: Expected output.</figcaption>
# </figure>

# %%
########################################
# TODO: implement



# ENDTODO
########################################

# %% [markdown]
# # Task 2: Rectify the RGB ID card image such that it aligns with the template

# %% [markdown]
# <figure class="image">
#   <img src="../figures/object_detection-expected_rectification_output.png" alt="" style="width: 6.4in;"/>
#   <figcaption>Figure 2: Expected output.</figcaption>
# </figure>

# %%
########################################
# TODO: implement



# ENDTODO
########################################

# %% [markdown]
# # Task 3: Crop the facial photograph, surname and given name

# %% [markdown]
# - Specify the coordinates of the facial photograph and the name and surname fields manually.
#
# <figure class="image">
#   <img src="../figures/object_detection-expected_crop_output.png" alt="" style="width: 12.8in;"/>
#   <figcaption>Figure 3: Expected output.</figcaption>
# </figure>

# %%
########################################
# TODO: implement



# ENDTODO
########################################

# %% [markdown]
# # Task 4: Use easyocr to read the surname and given name

# %% [markdown]
# - You only need two lines of code for OCR
#   ``` python
#   reader = easyocr.Reader(['cs'])
#   ... = reader.readtext(...)
#   ```
# - You may need to preprocess the ROIs a little bit in order to get more reliable results with easyocr.
#
# <figure class="image">
#   <img src="../figures/object_detection-expected_ocr_output.png" alt="" style="width: 3.2in;"/>
#   <figcaption>Figure 4: Expected output.</figcaption>
# </figure>

# %%
########################################
# TODO: implement



# ENDTODO
########################################

# %% [markdown]
# # Task 5: Refactor the detection into a single function `ocr_cze_id` and demonstrate on other images

# %% [markdown]
# - Use these validation images
#   ``` python
#   val_images = [
#       '../data/10_cze_id/CA10_01.jpg',
#       '../data/10_cze_id/HA10_06.jpg',
#       '../data/10_cze_id/HS10_12.jpg',
#       '../data/10_cze_id/KA10_01.jpg',
#       '../data/10_cze_id/KS10_02.jpg',
#       '../data/10_cze_id/PA10_30.jpg',
#       '../data/10_cze_id/TA10_01.jpg',
#       '../data/10_cze_id/TS10_01.jpg'
#   ]
#   ```
# - The OCR does not have to work perfectly.

# %%
def ocr_cze_id(scn_rgb: np.ndarray) -> tuple[np.ndarray, str, str]:
    """
    Args:
        scn_rgb: RGB image of the scene
    Returns:
        tuple of:
            - RGB photo of the face (np.ndarray)
            - name (string)
            - surname (string)
    """

    ########################################
    # TODO: implement

    raise NotImplementedError

    # ENDTODO
    ########################################

    return photo_rgb, name, surname

# %%
########################################
# TODO: implement



# ENDTODO
########################################
