# %% [markdown]
# # Morphology for image processing

# %% [markdown]
# - In this assignment, we will count objects in an non-uniformly illuminated scene.
# - We'll use the [top-hat](https://en.wikipedia.org/wiki/Top-hat_transform) transform to remove background.
# - This will enable easy object segmentation using thresholding and subsequent calculation of statistics.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import skimage.morphology
import skimage.util

# %%
plt.rcParams['figure.constrained_layout.use'] = True
np.set_printoptions(threshold=20, edgeitems=10, linewidth=140, precision=3, suppress=True)

# %%
rgb = skimage.io.imread('../data/rice.bmp')
gray = skimage.color.rgb2gray(rgb)

# %%
fig, axes = plt.subplots(1, 2)
axes[0].imshow(rgb)
axes[1].imshow(gray, cmap='gray', vmin=0, vmax=1);

# %% [markdown]
# # Task 1: background removal & thresholding

# %% [markdown]
# - Use top-hat grayscale morphology to remove the non-uniform background of the rice image and threshold using an appropriate value.
# - Morphological top-hat operation is defined as
#   ```
#   tophat(image) = image - grayscale_open(image, structuring_elem)
#   ```
# - The result is a grayscale image with he background removed and rice grains clearly visible.
# - Threshold the top-hat image using a value determined by Otsu's method.
#
# <figure class="image">
#   <img src="../figures/tophat-expected_tophat_outputs.png" alt="" style="width: 12.8in;"/>
#   <figcaption>Figure 1: Expected outputs.</figcaption>
# </figure>

# %%
########################################
# TODO: implement

raise NotImplementedError

# ENDTODO
########################################

# %% [markdown]
# # Task 2: rice grains statistics

# %% [markdown]
# - Count how many grains there are and calculate their average length and width (thickness).
# - In order to get the necessary information about objects, you can use whatever functions, e.g.
#   - `skimage.measure.regionprops`
#   - or OpenCV's functions `connectedComponentsWithStats`, `findContours` and/or `minAreaRect` as shown below.

# %%
########################################
# TODO: implement

raise NotImplementedError

# ENDTODO
########################################

# %%
print('number of grains:', num_grains) 
print('average length:', average_length)
print('average width:', average_width)
