# %% [markdown]
# # Object segmentation

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import skimage.feature
import skimage.filters
import skimage.measure
import skimage.segmentation

# %% [markdown]
# # Task 1: segment Number 5 from the `robot.bmp` image

# %% [markdown]
# - Use one of the methods described in the lecture [segmentation](../lectures/segmentation.ipynb).
# - Recommended approach is to use the [GrabCut method](https://docs.opencv.org/3.4/d8/d83/tutorial_py_grabcut.html).
#
# <figure class="image">
#   <img src="../figures/object_segmentation-expected_output.png" alt="" style="width: 6.4in;"/>
#   <figcaption>Figure 1: Expected output.</figcaption>
# </figure>

# %%
robot_rgb = cv.imread('../data/robot.bmp')[..., ::-1]

########################################
# TODO: implement



# ENDTODO
########################################
