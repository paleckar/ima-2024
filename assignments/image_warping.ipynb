# %% [markdown]
# # Init

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import skimage

# %%
plt.rcParams['figure.constrained_layout.use'] = True
np.set_printoptions(threshold=20, edgeitems=10, linewidth=140, precision=3, suppress=True)

# %% [markdown]
# # Task 1: implement linear interpolation in the `warp_inv` function
#
# - Complete implementation of the `warp_inv` from the [geometric_transformations lecture](../lectures/geometric_transformations.ipynb) so that it supports linear interpolation by passing `interp='linear'`.
#
# <figure class="image">
#   <img src="../figures/image_warping-expected_warp_inv_outputs.png" alt="" style="width: 12.8in;"/>
#   <figcaption>Figure 1: Expected outputs. Notice that image on the right is not pixelated.</figcaption>
# </figure>

# %%
def warp_inv(img: np.ndarray, A: np.ndarray, interp: str = 'nearest') -> np.ndarray:
    height, width = img.shape[:2]
    
    # get image corners and transform them
    X = np.array([0., width, width, 0.])
    Y = np.array([0., 0., height, height])
    XY = np.vstack((X, Y, np.ones(4)))
    XY_ = np.dot(A, XY)
    XY_ /= XY_[-1, :]
    ox_, oy_ =  XY_[0, :].min(),  XY_[1, :].min()
    
    # calculate the new size
    width_ = int(XY_[0, :].max() - XY_[0, :].min())
    height_ = int(XY_[1, :].max() - XY_[1, :].min())
    img_ = np.zeros((height_, width_), dtype=img.dtype)
    
    # invert transformation
    A_inv = np.linalg.inv(A)

    # helper function to safely get a value gray[y, x]
    def src_img_at(x, y):
        if 0 <= x < width and 0 <= y < height:
            return img[y, x]
        else:
            return 0
    
    # the main transformation loop
    for y_ in range(height_):
        for x_ in range(width_):
            # inverse transform
            x, y, z = np.dot(A_inv, [x_ + ox_, y_ + oy_, 1.])
            
            # normalize homogennous coordinates
            x /= z
            y /= z

            # interpolation
            if interp == 'nearest':
                x = int(0.5 + x)
                y = int(0.5 + y)    
                img_[y_, x_] = src_img_at(x, y)  # gray_at defined on line 17 of this function
            
            elif interp == 'linear':
                ########################################
                # TODO: implement
                
                raise NotImplementedError
                
                # ENDTODO
                ########################################
            
            else:
                raise ValueError(interp)
    
    return img_

# %%
rgb = cv2.imread('../data/robot.bmp')[..., ::-1]
gray = cv2.cvtColor(rgb, cv2.COLOR_RGB2GRAY)

A_hom = np.array([
    [ 0.9, -0.3, 50.],
    [-0.5,  1.0, 30.],
    [-0.002, -0.0015, 1]
])

gray_hom_nn = warp_inv(gray, A_hom, interp='nearest')
gray_hom_lin = warp_inv(gray, A_hom, interp='linear')

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 7))
axes[0].imshow(gray, cmap='gray', vmin=0., vmax=255, interpolation='none')
axes[1].imshow(gray_hom_nn, cmap='gray', vmin=0, vmax=255, interpolation='none');
axes[2].imshow(gray_hom_lin, cmap='gray', vmin=0, vmax=255, interpolation='none');

# %% [markdown]
# # Task 2: rotation around center of the image instead of origin=(0, 0)

# %% [markdown]
# - Implement the function `compute_rotation_params` that will receive the following parameters
#   - `degrees: float`, which is the number of degrees by which an image should be rotated,
#   - `height: int`, which is the number of rows of the image,
#   - `width: int`, which is the number of columns of the image,
# - The function will return
#   - `rot_mat` (matrix $\bold{A}$ of shape $3 \times 3$) such that when applied, the input image is rotated around its center instead of the top-left point. The matrix should correspond to "forward" transformation, i.e. the user must first manually invert it before using it in `warp_inv` or `skimage.transform.warp`.
#   - `rot_height: int`, which is the number of rows of the *rotated* image,
#   - `rot_width: int`, which is the number of columns of the *rotated* image.
# - It must work for arbitray angle `degrees`.
# - Use the `warp_inv` function or `skimage.transform.warp` to demonstrate functionality for various angles.
#
# *Hint*: You need to set the translation offsets $t_x$ and $t_y$ to correct values.
#
# <figure class="image">
#   <img src="../figures/image_warping-expected_rot_outputs.png" alt="" style="width: 12.8in;"/>
#   <figcaption>Figure 2: Expected outputs. Notice that images are rotated around their center.</figcaption>
# </figure>

# %%
rgb = cv2.imread('../data/robot.bmp')[..., ::-1]

# %%
plt.imshow(rgb);

# %%
def compute_rotation_params(degrees: float, height: int, width: int) -> tuple[np.ndarray, int, int]:
    ########################################
    # TODO: implement
    
    raise NotImplementedError
    
    # ENDTODO
    ########################################

    return rot_mat, rot_height, rot_width

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 7))
for deg, ax in zip([30, 60, -30], axes):
    rot_mat, rot_height, rot_width = compute_rotation_params(deg, *rgb.shape[:2])
    rgb_rot = skimage.transform.warp(rgb, np.linalg.inv(rot_mat), output_shape=(rot_height, rot_width))
    ax.imshow(rgb_rot, interpolation='none')

# %% [markdown]
# # Task 3: Transformation estimation in OpenCV

# %% [markdown]
# - Re-implement the example of the region of interest (ROI) extraction using transformation estimation that's in the notebook `geom-transform.ipynb` **using OpenCV**.
# - Apply the method to extract the Sudoku grid from the image `data/sudoku-alt3.jpg`.
# - Mark the corner points in the image manually.
# - The resulting ROI should be a square image with the side length divisible by 9.
#
# *Hint*: you'll probably need the functions `findHomography` and `warpPerspective`.
#
# <figure class="image">
#   <img src="../figures/image_warping-expected_transf_est_outputs.png" alt="" style="width: 12.8in;"/>
#   <figcaption>Figure 3: Expected outputs.</figcaption>
# </figure>

# %%
rgb = cv2.imread('../data/sudoku-alt3.jpg')[..., ::-1]

# %%
########################################
# TODO: implement

raise NotImplementedError

# ENDTODO
########################################
